# %% [markdown]
# # ***`[ 🌏  Abdiabyev Jasurbek](https://t.me/abd1bayev)`***
#
# # ***Pandas kutubxonasi:***
# # Ma'lumotlar olimlari uchun ma'lumotlarni manipulyatsiya qilish va tahlil qilish uchun eng ko'p afzal qilingan vositalardan biri bo'lib, ma'lumotlarni vizualizatsiya qilish uchun matplotlib va ​​Pandas qurilgan Python-da ilmiy hisoblash uchun fundamental kutubxona bo'lgan  NumPy yonida.**
#
# # ***Tez, moslashuvchan va ifodali Pandas ma'lumotlar tuzilmalari haqiqiy dunyo ma'lumotlarini tahlil qilishni sezilarli darajada osonlashtirish uchun mo'ljallangan, ammo bu uni endi boshlayotganlar uchun darhol bo'lmasligi mumkin. Ushbu paketga juda ko'p funksiyalar kiritilganligi sababli, variantlar juda ko'p.***
#
# # ***Aynan shu erda Pandas cheat varaqlari foydali bo'lishi mumkin. ***
#
# # ***Bu Pandas asoslari boʻyicha tezkor qoʻllanma boʻlib, siz Python bilan maʼlumotlaringiz bilan kurashishni boshlashingiz kerak boʻladi. ***
#
# # ***Shunday qilib, agar siz Pandas bilan ma'lumotlar fanlari bo'yicha sayohatni endi boshlayotgan bo'lsangiz yoki hali boshlamaganlar uchun uni o'rganishni osonlashtirish uchun qo'llanma sifatida ishlatishingiz mumkin. haqida va undan foydalaning. ***
#
# # ***Python-da ma'lumotlar faniga oid Pandas Cheat Sheet***
#
# # ***Pandas firibgarlik varaqasi sizga Pandas kutubxonasi asoslari boʻyicha yoʻl-yoʻriq koʻrsatadi, maʼlumotlar tuzilmalaridan kiritish-chiqarish, tanlash, indekslar yoki ustunlarni tushirish, saralash va tartiblash, qoʻllash uchun siz ishlayotgan maʼlumotlar tuzilmalarining asosiy maʼlumotlarini olish. funktsiyalari va ma'lumotlarni moslashtirish.***
#
# # ***Muxtasar qilib aytganda, Python bilan ma'lumotlar fanini o'rganishni boshlash uchun kerak bo'lgan hamma narsa!***
#
# # ***Ko'proq o'rganishni xohlaysizmi? Intermediate Python For Data Science kursini hozir bepul boshlang yoki Pandas DataFrame oʻquv qoʻllanmamizni sinab koʻring ! ***

# %% [markdown]
# ![Pandas_Cheat_Sheet_for_Data_Science_in_Python_hqirhp.webp](data:image/webp;base64,...)

# %%
import pandas as pd

# %% [markdown]
# # ***Pandas ma'lumotlar tuzilmalari***
# # Seriya
# # ***Har qanday ma'lumot turini saqlashga qodir bo'lgan bir o'lchovli etiketli massiv***

# %%
s = pd.Series([3, -5, 7, 4], index=['a','b','c','d'])
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# # ***DataFrame***
# # ***Potensial har xil turdagi ustunlarga ega bo'lgan ikki o'lchovli etiketli ma'lumotlar strukturasi***

# %%
data = {'Country': ['Belgium', 'India', 'Brazil'],
        'Capital': ['Brussels', 'New Delhi', 'Brasilia'],
        'Population': [11190846, 1303171035, 207847528]}

df = pd.DataFrame(data,columns=['Country', 'Capital', 'Population'])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %% [markdown]
# # ***Yordam so'rash***

# %%
help(pd.Series.loc)
# Out:
# Help on property:
#
#     Access a group of rows and columns by label(s) or a boolean array.
#
#     ``.loc[]`` is primarily label based, but may also be used with a
#     boolean array.
#
#     Allowed inputs are:
#
#     - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#       interpreted as a *label* of the index, and **never** as an
#       integer position along the index).
#     - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#     - A slice object with labels, e.g. ``'a':'f'``.
#
#       .. warning:: Note that contrary to usual python slices, **both** the
#           start and the stop are included
#
#     - A boolean array of the same length as the axis being sliced,
#       e.g. ``[True, False, True]``.
#     - An alignable boolean Series. The index of the key will be aligned before
#       masking.
#     - An alignable Index. The Index of the returned selection will be the input.
#     - A ``callable`` function with one argument (the calling Series or
# ...

# %% [markdown]
# # ***I/U***
# # ***CSV-ga o'qing va yozing***

# %%
pd.read_csv('test.csv', header=None, nrows=5)

# %% [markdown]
# # ***Bitta fayldan bir nechta varaqlarni o'qing***

# %%
xlsx = pd.ExcelFile('file.xls')
df = pd.read_excel(xlsx, 'Sheet1')

# %% [markdown]
# # ***Excelga o'qish va yozish***

# %%
pd.read_excel('file.xlsx')
df.to_excel('dir/myDataFrame.xlsx', sheet_name='Sheet1')

# %% [markdown]
# # ***SQL so'rovi yoki ma'lumotlar bazasi jadvaliga o'qish va yozish***
#
# # **(read_sql() bu read_sql_table() va read_sql_query() atrofidagi qulaylik paketidir)**

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
pd.read_sql(SELECT * FROM my_table;, engine)

# %%
pd.read_sql_table('my_table', engine)

# %%
pd.read_sql_query(SELECT * FROM my_table;', engine)

# %%
df.to_sql('myDf', engine)

# %% [markdown]
# # ***Tanlash***
# # Olish
#
# *Bitta* elementni oling

# %%
s['b']
# Out:
# -5

# %% [markdown]
# # ***DataFrame to'plamini oling***

# %%
df[1:]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasilia   207847528

# %% [markdown]
# # ***Tanlash', Mantiqiy indekslash va sozlash***
# # Lavozim bo'yicha
# # **Satr va ustun bo'yicha bitta qiymatni tanlang**

# %%
df.iloc([0], [0])

# %%
df.iat([0], [0])

# %% [markdown]
# # ***Qator va ustunlarni tanlang***

# %%
df.ix[1, 'Capital']

# %% [markdown]
# # ***Mantiqiy indekslash***
# ## *Qiymati >1 bo'lmagan s seriyasi*

# %%
s[~(s > 1)]
# Out:
# b   -5
# dtype: int64

# %% [markdown]
# # ***s bu yerda qiymat <-1 yoki >2***

# %%
s[(s < -1)| (s > 2)]
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# # ***DataFrame-ni sozlash uchun filtrdan foydalaning***

# %%
df[df['Population']>1200000000]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035

# %% [markdown]
# # ***Sozlama***
# # **s seriyasining a indeksini 6 ga o'rnating**

# %%
s['a'] = 6
s
# Out:
# a    6
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# # ***Tutish***
# # **Qatorlardan qiymatlarni tushirish (eksa=0)**

# %%
s.drop(['a', 'c'])
# Out:
# b   -5
# d    4
# dtype: int64

# %% [markdown]
# # **Ustunlardan qiymatlarni tushirish (eksa = 1)**

# %%
df.drop('Country', axis=1)
# Out:
#      Capital  Population
# 0   Brussels    11190846
# 1  New Delhi  1303171035
# 2   Brasilia   207847528

# %% [markdown]
# # ***Saralash va tartiblash***
# # **O'q bo'ylab teglar bo'yicha saralash**

# %%
df.sort_index()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %% [markdown]
# # O'q bo'ylab qiymatlar bo'yicha **tartiblang**

# %%
df.sort_values(by='Country')
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 2   Brazil   Brasilia   207847528
# 1    India  New Delhi  1303171035

# %% [markdown]
# # Yozuvlarga darajalarni belgilang

# %%
df.rank()
# Out:
#    Country  Capital  Population
# 0      1.0      2.0         1.0
# 1      3.0      3.0         3.0
# 2      2.0      1.0         2.0

# %% [markdown]
# # ***Series/DataFrame ma'lumotlarini olish***
#
# # **Asosiy ma'lumotlar**
#
# # (satrlar, ustunlar)

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# # Indeksni tavsiflang

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# # DataFrame ustunlarini tavsiflang

# %%
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %% [markdown]
# # DataFrame haqida ma'lumot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     3 non-null      object
#  1   Capital     3 non-null      object
#  2   Population  3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# # NA bo'lmagan qiymatlar soni

# %%
df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %% [markdown]
# # ***Xulosa***
# # **Qadriyatlar yig'indisi**

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Capital       BrusselsNew DelhiBrasilia
# Population                   1522209409
# dtype: object

# %% [markdown]
# # Qiymatlarning yig'indisi

# %%
df.cumsum()
# Out:
#               Country                    Capital  Population
# 0             Belgium                   Brussels    11190846
# 1        BelgiumIndia          BrusselsNew Delhi  1314361881
# 2  BelgiumIndiaBrazil  BrusselsNew DelhiBrasilia  1522209409

# %% [markdown]
# # Minimal/maksimal qiymatlar

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasilia
# Population    11190846
# dtype: object

# %%
df.max()
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# dtype: object

# %% [markdown]
# # Minimal/Maksimal indeks qiymati

# %%
df.idxmin()
df.idxmex()

# %% [markdown]
# # Xulosa statistikasi

# %%
df.describe()
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %% [markdown]
# # Qadriyatlar o'rtacha

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Population    5.074031e+08
# dtype: float64

# %% [markdown]
# ## Qiymatlar medianasi

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Population    207847528.0
# dtype: float64

# %% [markdown]
# # ***Funktsiyalarni qo'llash***

# %%
f = lambda x: x*2
f
# Out:
# <function __main__.<lambda>>

# %% [markdown]
# # Funktsiyani qo'llash

# %%
df.apply(f)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels    22381692
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasiliaBrasilia   415695056

# %% [markdown]
# # Funktsiyani element bo'yicha qo'llang

# %%
df.applymap(f)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels    22381692
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasiliaBrasilia   415695056

# %% [markdown]
# # ***Ichki ma'lumotlarni moslashtirish***
# # NA qiymatlari bir-biriga mos kelmaydigan indekslarda kiritiladi:

# %%
s3 = pd.Series([7,-2,3], index=['a', 'c', 'd'])
s + s3
# Out:
# a    13.0
# b     NaN
# c     5.0
# d     7.0
# dtype: float64

# %% [markdown]
# # ***To'ldirish usullari bilan arifmetik amallar***
#
# # Shuningdek, siz to'ldirish usullari yordamida ichki ma'lumotlarni moslashtirishni o'zingiz qilishingiz mumkin:

# %%
s.add(s3, fill_value=0)
# Out:
# a    13.0
# b    -5.0
# c     5.0
# d     7.0
# dtype: float64

# %%
s.sub(s3, fill_value=2)
s.sub(s3, fill_value=4)
s.sub(s3, fill_value=3)
# Out:
# a   -1.0
# b   -7.0
# c    9.0
# d    1.0
# dtype: float64

# %% [markdown]
# # ***Thank you all!***
